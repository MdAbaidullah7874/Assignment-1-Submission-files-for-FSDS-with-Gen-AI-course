# %% [markdown]
# # Assignment 1

# %%
# Assignment 1
temperature = float(input("Enter the current temperature in Celsius: "))

if temperature < 10:
    print("It's too cold!")
elif temperature <= 25:
    print("It's cool outside")
else:
    print("It's hot outside!")
# Out:
# Enter the current temperature in Celsius:  8
# It's too cold!

# %% [markdown]
# # Assignment 2

# %%
# Assignment 2
account_balance = float(input("Enter your current account balance: "))
withdraw_amount = float(input("Enter the amount you want to withdraw: "))

if withdraw_amount > account_balance:
    print("Insufficient Balance")
else:
    remaining_balance = account_balance - withdraw_amount
    print("Transaction Successful")
    print("Your remaining balance is: ", remaining_balance)
# Out:
# Enter your current account balance:  1000
# Enter the amount you want to withdraw:  1000
# Transaction Successful
# Your remaining balance is:  0.0

# %% [markdown]
# # Assignment 3

# %%
# Assignment 3
marks = float(input("Enter your marks (0-100): "))

if marks >= 90:
    print("Grade: A+")
elif marks >= 80:
    print("Grade: A")
elif marks >= 70:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
else:
    print("Grade: Fail")
# Out:
# Enter your marks (0-100):  75
# Grade: B

# %% [markdown]
# # Assignment 4

# %%
# Assignment 4
age = int(input("Enter your age: "))

if age < 5:
    print("Ticket Price: Free")
elif age <= 18:
    print("Ticket Price: 50% Discount")
elif age >= 60:
    print("Ticket Price: 30% Discount")
else:
    print("Ticket Price: Full Price")
# Out:
# Enter your age:  20
# Ticket Price: Full Price

# %% [markdown]
# # Assignment 5

# %%
# Assignment 5
total_bill = float(input("Enter the total bill amount: "))

if total_bill > 1000:
    discount = total_bill * 0.10
    final_bill = total_bill - discount
else:
    final_bill = total_bill

print("Your final payable bill is: ", final_bill)
# Out:
# Enter the total bill amount:  1500
# Your final payable bill is:  1350.0

# %% [markdown]
# # Assignment 6

# %%
# Assignment 6
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "12345":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username:  mdabaidullah7432
# Enter password:  677785dcvfh
# Invalid Credentials

# %%
# Assignment 6
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "12345":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username:  admin
# Enter password:  12345
# Login Successful

# %% [markdown]
# # Assignment 7

# %%
# Assignment 7
color = input("Enter a color (red, yellow, green): ").lower()

if color == "red":
    print("Stop")
elif color == "yellow":
    print("Ready to go")
elif color == "green":
    print("Go")
else:
    print("Invalid color")
# Out:
# Enter a color (red, yellow, green):  red
# Stop

# %%
# Assignment 7
color = input("Enter a color (red, yellow, green): ").lower()

if color == "red":
    print("Stop")
elif color == "yellow":
    print("Ready to go")
elif color == "green":
    print("Go")
else:
    print("Invalid color")
# Out:
# Enter a color (red, yellow, green):  pink
# Invalid color

# %% [markdown]
# # Assignment 8

# %%
# Assignment 8
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a Leap Year")
else:
    print(year, "is Not a Leap Year")
# Out:
# Enter a year:  2025
# 2025 is Not a Leap Year

# %% [markdown]
# # Assignment 9

# %%
# Assignment 9
age = int(input("Enter your age: "))
qualification = input("Enter your qualification (e.g., graduate): ").lower()

if age >= 18 and qualification == "graduate":
    print("Eligible for Job")
else:
    print("Not Eligible")
# Out:
# Enter your age:  20
# Enter your qualification (e.g., graduate):  undergraduate
# Not Eligible

# %% [markdown]
# # Assignment 10

# %%
# Assignment 10
units = int(input("Enter number of units consumed: "))

bill = 0.0

if units <= 100:
    bill = units * 5
elif units <= 200:
    first_100_bill = 100 * 5
    remaining_units = units - 100
    remaining_bill = remaining_units * 7
    bill = first_100_bill + remaining_bill
else:
    first_100_bill = 100 * 5
    second_100_bill = 100 * 7
    remaining_units = units - 200
    remaining_bill = remaining_units * 10
    bill = first_100_bill + second_100_bill + remaining_bill

print("Total payable amount:", bill, "RS")
# Out:
# Enter number of units consumed:  170
# Total payable amount: 990 RS

# %% [markdown]
# # --END Assignment 1 to 10 END--
